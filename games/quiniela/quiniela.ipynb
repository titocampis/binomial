# %%
import numpy as np
import matplotlib.pyplot as plt
import math

premios = [
        {
        "date" : "03 Mayo 2023",
        "recaudacion" : 1464256.50,
        "apuestas" : 0,
        "10" : {
            "full" : 0,
            "people" : 153617,
            "unitary" : 0,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" :  45626,
            "unitary" : 0,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 8705,
            "unitary" : 0,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 883,
            "unitary" : 0,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 11,
            "unitary" : 0,
            "per" : 0
        }
    },
        {
        "date" : "07 Mayo 2023",
        "recaudacion" : 1578344.25,
        "apuestas" : 0,
        "10" : {
            "full" : 0,
            "people" : 8386,
            "unitary" : 0,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" :  1222,
            "unitary" : 0,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 116,
            "unitary" : 0,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 4,
            "unitary" : 0,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 1,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "14 Mayo 2023",
        "recaudacion" : 3040607.25,
        "apuestas" : 0,
        "10" : {
            "full" : 0,
            "people" : 19110,
            "unitary" : 0,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" :  2570,
            "unitary" : 0,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 247,
            "unitary" : 0,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 16,
            "unitary" : 0,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 0,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "21 Mayo 2023",
        "recaudacion" : 3012967.50,
        "apuestas" : 0,
        "10" : {
            "full" : 0,
            "people" : 55841,
            "unitary" : 0,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" :  10584,
            "unitary" : 0,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 1123,
            "unitary" : 0,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 62,
            "unitary" : 0,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 1,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "24 Mayo 2023",
        "recaudacion" : 1390638.75,
        "apuestas" : 1854185,
        "10" : {
            "full" : 0,
            "people" : 4178,
            "unitary" : 29.96,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" : 616,
            "unitary" : 169.31,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 62,
            "unitary" : 1682.22,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 4,
            "unitary" : 26074.48,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 0,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "28 Mayo 2023",
        "recaudacion" : 3172962,
        "apuestas" : 4230616,
        "10" : {
            "full" : 0,
            "people" : 71961,
            "unitary" : 3.97,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" : 13667,
            "unitary" : 17.41,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 1531,
            "unitary" : 155.44,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 73,
            "unitary" : 3259.89,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 0,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "13 Agosto 2023",
        "recaudacion" : 2664055.50,
        "apuestas" : 3552074,
        "10" : {
            "full" : 0,
            "people" : 1824,
            "unitary" : 131.45,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" : 278,
            "unitary" : 718.72,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 30,
            "unitary" : 6660.14,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 2,
            "unitary" : 99902.08,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 0,
            "unitary" : 0,
            "per" : 0
        }
    },
    {
        "date" : "20 Agosto 2023",
        "recaudacion" : 2789930.25,
        "apuestas" : 3719907,
        "10" : {
            "full" : 0,
            "people" : 124328,
            "unitary" : 2.02,
            "per" : 0
        },
        "11" : {
            "full" : 0,
            "people" : 28391,
            "unitary" : 7.37,
            "per" : 0
        },
        "12" : {
            "full" : 0,
            "people" : 3989,
            "unitary" : 52.46,
            "per" : 0
        },
        "13" : {
            "full" : 0,
            "people" : 317,
            "unitary" : 660.08,
            "per" : 0
        },
        "14" : {
            "full" : 0,
            "people" : 10,
            "unitary" : 44638.88,
            "per" : 0
        }
    }
]

# Vectores de datos
recaudacion = []
apuestas = []
# people 1 = 10, 2 = 11, 3 = 12...
people = np.empty([5,len(premios)])
pr_unit = np.empty([5,len(premios)])
percent = np.empty([5,len(premios)])
j = 0
for quiniela in premios:
  for i in range(10,15):
    # Rellenado de campos vacios
    if (quiniela[str(i)]["unitary"] == 0 and quiniela[str(i)]["people"] != 0):
      if (i == 10):
        fact = 9 / 100
      elif (i < 14):
        fact = 7.5 / 100
      else:
        fact = 16 / 100
      quiniela[str(i)]["unitary"] = fact * quiniela["recaudacion"] / quiniela[str(i)]["people"]

    if (quiniela["apuestas"] == 0):
      quiniela["apuestas"] = round(1/0.75 * quiniela["recaudacion"])

    quiniela[str(i)]["full"] = quiniela[str(i)]["people"] * quiniela[str(i)]["unitary"]
    quiniela[str(i)]["per"] = 100 * quiniela[str(i)]["people"] / quiniela["apuestas"]


    # Vectores de datos
    people[i-10][j] = (quiniela[str(i)]["people"])
    pr_unit[i-10][j] = (quiniela[str(i)]["unitary"])
    percent[i-10][j] = (quiniela[str(i)]["per"])
  recaudacion.append(quiniela["recaudacion"])
  apuestas.append(quiniela["apuestas"])
  j += 1

for elem in premios:
  for key, val in elem.items():
    print(key, ":", val)
  print()
# Out:
# date : 03 Mayo 2023
# recaudacion : 1464256.5
# apuestas : 1952342
# 10 : {'full': 131783.085, 'people': 153617, 'unitary': 0.8578678466575964, 'per': 7.868344787952111}
# 11 : {'full': 109819.2375, 'people': 45626, 'unitary': 2.406944231359313, 'per': 2.3369880891769985}
# 12 : {'full': 109819.2375, 'people': 8705, 'unitary': 12.615650488225159, 'per': 0.4458747494035369}
# 13 : {'full': 109819.2375, 'people': 883, 'unitary': 124.3705973952435, 'per': 0.0452277316166942}
# 14 : {'full': 234281.04, 'people': 11, 'unitary': 21298.276363636363, 'per': 0.0005634258751796561}
#
# date : 07 Mayo 2023
# recaudacion : 1578344.25
# apuestas : 2104459
# 10 : {'full': 142050.98249999998, 'people': 8386, 'unitary': 16.939063021702836, 'per': 0.3984872121528621}
# 11 : {'full': 118375.81874999999, 'people': 1222, 'unitary': 96.87055544189852, 'per': 0.05806718021116116}
# 12 : {'full': 118375.81874999999, 'people': 116, 'unitary': 1020.4811961206896, 'per': 0.005512105486493203}
# ...

# %%
print("Vector de recaudaciones")
print(recaudacion,"\n")
print("Vector de apuestas")
print(apuestas,"\n")
print("Relación entre ambos")
print(np.divide(np.array(recaudacion),np.array(apuestas)),"\n")

plt.figure(1)
plt.title("Recaudaciones y apuestas")
axis_x = range(1,len(premios)+1)
plt.plot(axis_x, recaudacion, 'oy-', label="recaudación")
plt.plot(axis_x, apuestas, 'ob-', label="apuestas")
plt.legend(loc = 'lower right')
plt.ylabel('Euros')

# Gráficas
plt.figure(2)
fig, axs = plt.subplots(3)
axis_x = range(1,len(premios)+1)
fig.suptitle('People and prize for 10')
axs[0].plot(axis_x, people[0], 'o-')
axs[0].set_ylabel('people')
axs[1].plot(axis_x, percent[0], 'o-')
axs[1].set_ylabel('%')
axs[2].plot(axis_x, pr_unit[0], 'or-')
axs[2].set_ylabel('€')
plt.show()
print("\np :", people[0])
print("% : ", percent[0])
print("€ : ", pr_unit[0])

plt.figure(1)
fig, axs = plt.subplots(3)
axis_x = range(1,len(premios)+1)
fig.suptitle('People and prize for 11')
axs[0].plot(axis_x, people[1], 'o-')
axs[0].set_ylabel('people')
axs[1].plot(axis_x, percent[1], 'o-')
axs[1].set_ylabel('%')
axs[2].plot(axis_x, pr_unit[1], 'or-')
axs[2].set_ylabel('€')
plt.show()
print("\np :", people[1])
print("% : ", percent[1])
print("€ : ", pr_unit[1])

plt.figure(1)
fig, axs = plt.subplots(3)
axis_x = range(1,len(premios)+1)
fig.suptitle('People and prize for 12')
axs[0].plot(axis_x, people[2], 'o-')
axs[0].set_ylabel('people')
axs[1].plot(axis_x, percent[2], 'o-')
axs[1].set_ylabel('%')
axs[2].plot(axis_x, pr_unit[2], 'or-')
axs[2].set_ylabel('€')
plt.show()
print("\np :", people[2])
print("% : ", percent[2])
print("€ : ", pr_unit[2])


plt.figure(1)
fig, axs = plt.subplots(3)
axis_x = range(1,len(premios)+1)
fig.suptitle('People and prize for 13')
axs[0].plot(axis_x, people[3], 'o-')
axs[0].set_ylabel('people')
axs[1].plot(axis_x, percent[3], 'o-')
axs[1].set_ylabel('%')
axs[2].plot(axis_x, pr_unit[3], 'or-')
axs[2].set_ylabel('€')
plt.show()
print("\np :", people[3])
print("% : ", percent[3])
print("€ : ", pr_unit[3])

plt.figure(1)
fig, axs = plt.subplots(3)
axis_x = range(1,len(premios)+1)
fig.suptitle('People and prize for 14')
axs[0].plot(axis_x, people[4], 'o-')
axs[0].set_ylabel('people')
axs[1].plot(axis_x, percent[4], 'o-')
axs[1].set_ylabel('%')
axs[2].plot(axis_x, pr_unit[4], 'or-')
axs[2].set_ylabel('€')
plt.show()
print("\np :", people[4])
print("% : ", percent[4])
print("€ : ", pr_unit[4])
# Out:
# Vector de recaudaciones
# [1464256.5, 1578344.25, 3040607.25, 3012967.5, 1390638.75, 3172962, 2664055.5, 2789930.25]
#
# Vector de apuestas
# [1952342, 2104459, 4054143, 4017290, 1854185, 4230616, 3552074, 3719907]
#
# Relación entre ambos
# [0.75 0.75 0.75 0.75 0.75 0.75 0.75 0.75]
# p : [153617.   8386.  19110.  55841.   4178.  71961.   1824. 124328.]
# % :  [7.86834479 0.39848721 0.47136966 1.39001665 0.22532811 1.70095797
#  0.05135028 3.34223409]
# € :  [  0.85786785  16.93906302  14.31997135   4.85605693  29.96
#    3.97       131.45         2.02      ]
# p : [45626.  1222.  2570. 10584.   616. 13667.   278. 28391.]
# % :  [2.33698809 0.05806718 0.06339194 0.26346119 0.03322214 0.32304988
#  0.00782641 0.76321801]
# € :  [  2.40694423  96.87055544  88.73367461  21.35039328 169.31
#   17.41       718.72         7.37      ]
# p : [8705.  116.  247. 1123.   62. 1531.   30. 3989.]
# % :  [0.44587475 0.00551211 0.00609253 0.02795417 0.00334379 0.03618858
#  0.00084458 0.10723386]
# ...

# %%
# Media de datos
med_people = []
med_percent = []
med_unitary = []

med_apuestas = round(np.mean(apuestas))
for i in range(len(people)):
  med_people.append(np.mean(people[i]))
  med_percent.append(np.mean(percent[i]))
  med_unitary.append(np.mean(pr_unit[i]))

print("Media de participación (personas)):", med_apuestas)
print()
print("Media de personas que aciertan (10, 11, 12, 13 y 14 respectivamente):", med_people)
print("Media % de personas que aciertan (10, 11, 12, 13 y 14 respectivamente):", med_percent)
print("Media de premios unitarios (para 10, 11, 12, 13 y 14 respectivamente):", med_unitary)
# Out:
# Media de participación (personas)): 3185627
#
# Media de personas que aciertan (10, 11, 12, 13 y 14 respectivamente): [54905.625, 12869.25, 1975.375, 170.125, 2.875]
# Media % de personas que aciertan (10, 11, 12, 13 y 14 respectivamente): [1.9310110955836568, 0.4811531056424293, 0.07913054590136566, 0.0072343824981602614, 0.0001130825441767863]
# Media de premios unitarios (para 10, 11, 12, 13 y 14 respectivamente): [25.546619893491897, 140.2714459458082, 1338.4800482179644, 22189.05256490878, 100068.37954545455]

# %%
# Probabilidades teoricas
p = 1/3

probs = []
probs_full = []
med_per = np.array(med_percent) / 100
for k in range(10,15):
  probs.append(math.comb(14, k) * pow(p,k) * pow(1-p,14-k))

plt.figure(1)
axis_x = range(10, 15)
plt.bar(axis_x, probs)
plt.show()
print("\n", "Probabilidades teoricas de acertar: (10, 11, 12, 13 y 14 respectivamente) con p =", p)
print(np.array(probs))
print(np.around(1/np.array(probs)))
print("Probabilidad de que toque algo:", np.sum(probs), "= 1 /", round(1 / np.sum(probs)))
print("Pleno al 15 =", pow(p,14)/pow(4,2), "= 1 /", round(pow(4,2)/pow(p,14)), "\n")
plt.figure(1)
axis_x = range(10, 15)
plt.bar(axis_x, med_per, color="green")
plt.show()
print("\n Media % de personas que aciertan (10, 11, 12, 13 y 14 respectivamente) con p =", p)
print(med_per, "\n")

plt.figure(1)
axis_x = range(10, 15)
plt.plot(axis_x, np.array(abs(probs-med_per)), 'or')
plt.show()
print("\n Error (10, 11, 12, 13 y 14 respectivamente) con p = ", p)
print(np.array(abs(probs-med_per)), "\n")

for k in range(0,15):
  probs_full.append(math.comb(14, k) * pow(p,k) * pow(1-p,14-k))

plt.figure(1)
axis_x = range(0, 15)
plt.plot(axis_x, probs_full)
plt.show()
print("\n Funcion distribucion de probabilidad binomial de la Quiniela con p =", p)
print(probs_full, "\n")

MSE = np.square(np.subtract(probs, med_per)).mean()
print("MSE para p =", p, ":", MSE)
# Out:
#  Probabilidades teoricas de acertar: (10, 11, 12, 13 y 14 respectivamente) con p = 0.3333333333333333
# [3.34854773e-03 6.08826860e-04 7.61033576e-05 5.85410443e-06
#  2.09075158e-07]
# [2.990000e+02 1.643000e+03 1.314000e+04 1.708200e+05 4.782969e+06]
# Probabilidad de que toque algo: 0.004039541130205946 = 1 / 248
# Pleno al 15 = 1.306719738304805e-08 = 1 / 76527504
#  Media % de personas que aciertan (10, 11, 12, 13 y 14 respectivamente) con p = 0.3333333333333333
# [1.93101110e-02 4.81153106e-03 7.91305459e-04 7.23438250e-05
#  1.13082544e-06]
#  Error (10, 11, 12, 13 y 14 respectivamente) con p =  0.3333333333333333
# [1.59615632e-02 4.20270420e-03 7.15202101e-04 6.64897206e-05
#  9.21750284e-07]
#  Funcion distribucion de probabilidad binomial de la Quiniela con p = 0.3333333333333333
# ...

# %%
# Optimizacion MSE
MSE = 1000
MSE_vec = []
p_good = 0
prob = 0
for p in np.arange(0, 0.5, 0.01):
  new_probs = []
  for k in range(10,15):
    prob = math.comb(14, k) * pow(p,k) * pow(1-p,14-k)
    new_probs.append(prob)
  MSE_new = np.square(np.subtract(new_probs, med_per)).mean()
  MSE_vec.append(MSE_new)
  if (MSE_new <= MSE):
    MSE = MSE_new
    p_good = p
print(MSE_vec)
print(p_good)


plt.figure(1)
axis_x = np.arange(0, 0.5, 0.01)
plt.plot(axis_x, MSE_vec, 'r')
plt.show()
print("La probabilidad que mejor se adapta al MSE es p =", p_good)
# Out:
# [7.933252309417977e-05, 7.93325230941797e-05, 7.933252309410661e-05, 7.93325230901266e-05, 7.93325230250599e-05, 7.933252247624317e-05, 7.933251942293105e-05, 7.93325066447089e-05, 7.933246314952602e-05, 7.933233655957408e-05, 7.933201068327552e-05, 7.933125069055835e-05, 7.932961652463512e-05, 7.93263335766226e-05, 7.932010837660112e-05, 7.93088762805341e-05, 7.928946803528901e-05, 7.9257182890808e-05, 7.920525785820577e-05, 7.912422612805935e-05, 7.900116302957026e-05, 7.881882585632288e-05, 7.855470523271167e-05, 7.818002148652647e-05, 7.765872097142577e-05, 7.694655584117551e-05, 7.599036784602906e-05, 7.47277435878604e-05, 7.308726622448058e-05, 7.098965702135183e-05, 6.835017846962072e-05, 6.508275645874815e-05, 6.110636781461799e-05, 5.6354324716140704e-05, 5.0787159909959765e-05, 4.4409864548478185e-05, 3.729423988034502e-05, 2.9607079190475662e-05, 2.164478078464248e-05, 1.3874790433444044e-05, 6.983968750000497e-06, 1.9335659343189806e-06, 1.9960095995139006e-08, 2.93968161
# ...
